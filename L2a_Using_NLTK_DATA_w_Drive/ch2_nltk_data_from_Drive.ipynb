# %% [markdown]
# # Using nltk_data on your Google Drive
#
# (saves you from spamming the NLTK servers)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#setting the filepath to the data (you'll need it in other notebooks)
#!export NLTK_DATA="/content/drive/My Drive/Colab Notebooks/nltk_data/" does not seem to work on Colab

# %%
#setting the filepath to the data (you'll need it in other notebooks)
import nltk
nltk.data.path.append("/content/drive/My Drive/Colab Notebooks/nltk_data/")

# %% [markdown]
# ### Now... Let's get the data.

# %%
print ("importing text1, text2, text3 text4")
from nltk.book import (text1, text2, text3, text4)

#echo some values
print ("text2: ", text2)

print ("\n\n")
print ("text4: ", text4)
# Out:
# importing text1, text2, text3 text4
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail

# %%
text1.concordance("monstrous")
