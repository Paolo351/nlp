# %% [markdown]
# ##Working with WordNet##
#
# Based on http://www.nltk.org/book/ch02.html
#
# Other example uses apear also at http://www.nltk.org/howto/wordnet.html
#
# Most of the text is directly lifted from the above. Some modifiation are by WZ.

# %%
import nltk
print("working with nltk.corpus:  wordnet and stopwords")
# Out:
# working with nltk.corpus:  wordnet and stopwords

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nltk.data.path.append("/content/drive/My Drive/Colab Notebooks/nltk_data/")

# %%
from nltk.corpus import wordnet as wn
print("\nwn.synsets('motorcar')")
print(wn.synsets('motorcar'))
# Out:
# wn.synsets('motorcar')
# [Synset('car.n.01')]

# %%
print("wn.synset('car.n.01').lemmas():  ")
print(wn.synset('car.n.01').lemmas())
print("")
# Out:
# wn.synset('car.n.01').lemmas():
# [Lemma('car.n.01.car'), Lemma('car.n.01.auto'), Lemma('car.n.01.automobile'), Lemma('car.n.01.machine'), Lemma('car.n.01.motorcar')]

# %% [markdown]
# https://www.nltk.org/images/wordnet-hierarchy.png
# WordNet organizes words in hierarchies

# %%
motorcar = wn.synset('car.n.01')
types_of_motorcar = motorcar.hyponyms()
types_of_motorcar[0:len(types_of_motorcar)]
# Out:
# [Synset('ambulance.n.01'),
#  Synset('beach_wagon.n.01'),
#  Synset('bus.n.04'),
#  Synset('cab.n.03'),
#  Synset('compact.n.03'),
#  Synset('convertible.n.01'),
#  Synset('coupe.n.01'),
#  Synset('cruiser.n.01'),
#  Synset('electric.n.01'),
#  Synset('gas_guzzler.n.01'),
#  Synset('hardtop.n.01'),
#  Synset('hatchback.n.01'),
#  Synset('horseless_carriage.n.01'),
#  Synset('hot_rod.n.01'),
#  Synset('jeep.n.01'),
#  Synset('limousine.n.01'),
#  Synset('loaner.n.02'),
#  Synset('minicar.n.01'),
#  Synset('minivan.n.01'),
#  Synset('model_t.n.01'),
#  Synset('pace_car.n.01'),
#  Synset('racer.n.02'),
#  Synset('roadster.n.01'),
#  Synset('sedan.n.01'),
#  Synset('sport_utility.n.01'),
#  Synset('sports_car.n.01'),
#  Synset('stanley_steamer.n.01'),
#  Synset('stock_car.n.01'),
#  Synset('subcompact.n.01'),
#  Synset('touring_car.n.01'),
#  Synset('used-car.n.01')]

# %%
sorted(lemma.name() for synset in types_of_motorcar for lemma in synset.lemmas())
# Out:
# ['Model_T',
#  'S.U.V.',
#  'SUV',
#  'Stanley_Steamer',
#  'ambulance',
#  'beach_waggon',
#  'beach_wagon',
#  'bus',
#  'cab',
#  'compact',
#  'compact_car',
#  'convertible',
#  'coupe',
#  'cruiser',
#  'electric',
#  'electric_automobile',
#  'electric_car',
#  'estate_car',
#  'gas_guzzler',
#  'hack',
#  'hardtop',
#  'hatchback',
#  'heap',
#  'horseless_carriage',
#  'hot-rod',
#  'hot_rod',
#  'jalopy',
#  'jeep',
#  'landrover',
#  'limo',
#  'limousine',
#  'loaner',
#  'minicar',
#  'minivan',
#  'pace_car',
#  'patrol_car',
#  'phaeton',
#  'police_car',
#  'police_cruiser',
#  'prowl_car',
#  'race_car',
#  'racer',
#  'racing_car',
#  'roadster',
#  'runabout',
#  'saloon',
#  'secondhand_car',
#  'sedan',
#  'sport_car',
#  'sport_utility',
#  'sport_utility_vehicle',
#  'sports_car',
#  'squad_car',
#  'station_waggon',
#  'station_wagon',
#  'stock_car',
#  'subcompact',
#  'subcompact_car',
#  'taxi',
#  'taxicab',
#  'tourer',
#  'touring_car',
# ...

# %%
print("wn.synsets('house'): ")
print(wn.synsets('house')) 
print("")

print("wn.synset('house.v.02').lemmas(): ")
print(wn.synset('house.v.02').lemmas())
print("")
# Out:
# wn.synsets('house'):
# [Synset('house.n.01'), Synset('firm.n.01'), Synset('house.n.03'), Synset('house.n.04'), Synset('house.n.05'), Synset('house.n.06'), Synset('house.n.07'), Synset('sign_of_the_zodiac.n.01'), Synset('house.n.09'), Synset('family.n.01'), Synset('theater.n.01'), Synset('house.n.12'), Synset('house.v.01'), Synset('house.v.02')]
#
# wn.synset('house.v.02').lemmas():
# [Lemma('house.v.02.house'), Lemma('house.v.02.put_up'), Lemma('house.v.02.domiciliate')]

# %%
wn.synsets('king')
# Out:
# [Synset('king.n.01'),
#  Synset('king.n.02'),
#  Synset('baron.n.03'),
#  Synset('king.n.04'),
#  Synset('king.n.05'),
#  Synset('king.n.06'),
#  Synset('king.n.07'),
#  Synset('king.n.08'),
#  Synset('king.n.09'),
#  Synset('king.n.10')]

# %% [markdown]
# **More from NTL Ch2 Sections 5.2 and 5.3 -- More lexical relations**

# %%
print(motorcar.hypernyms())
#[Synset('motor_vehicle.n.01')]



paths = motorcar.hypernym_paths()
print(len(paths))
# Out:
# [Synset('motor_vehicle.n.01')]
# 2

# %%
[synset.name() for synset in paths[0]]
# Out:
# ['entity.n.01',
#  'physical_entity.n.01',
#  'object.n.01',
#  'whole.n.02',
#  'artifact.n.01',
#  'instrumentality.n.03',
#  'container.n.01',
#  'wheeled_vehicle.n.01',
#  'self-propelled_vehicle.n.01',
#  'motor_vehicle.n.01',
#  'car.n.01']

# %%
[synset.name() for synset in paths[1]]
# Out:
# ['entity.n.01',
#  'physical_entity.n.01',
#  'object.n.01',
#  'whole.n.02',
#  'artifact.n.01',
#  'instrumentality.n.03',
#  'conveyance.n.03',
#  'vehicle.n.01',
#  'wheeled_vehicle.n.01',
#  'self-propelled_vehicle.n.01',
#  'motor_vehicle.n.01',
#  'car.n.01']

# %%
#We can get the most general hypernyms (or root hypernyms) of a synset as follows:

motorcar.root_hypernyms()
# Out:
# [Synset('entity.n.01')]

# %% [markdown]
# "holonym" is a term that denotes a whole, a part of which is denoted by a second term. The word "face" is a holonym of the word "eye". (Wiktionary).
#
# What is the meaning of the word: "hypernym", "hyponym", "homonym"?

# %%
	
wn.synset('tree.n.01').part_meronyms()
# Out:
# [Synset('burl.n.02'),
#  Synset('crown.n.07'),
#  Synset('limb.n.02'),
#  Synset('stump.n.01'),
#  Synset('trunk.n.01')]

# %%
 wn.synset('tree.n.01').substance_meronyms()
# Out:
# [Synset('heartwood.n.01'), Synset('sapwood.n.01')]

# %%
wn.synset('tree.n.01').member_holonyms()
# Out:
# [Synset('forest.n.01')]

# %% [markdown]
# To see just how intricate things can get, consider the word mint, which has several closely-related senses. We can see that mint.n.04 is part of mint.n.02 and the substance from which mint.n.05 is made.

# %%
for synset in wn.synsets('mint', wn.NOUN):
   print(synset.name() + ':', synset.definition())
# Out:
# batch.n.02: (often followed by `of') a large number or amount or extent
# mint.n.02: any north temperate plant of the genus Mentha with aromatic leaves and small mauve flowers
# mint.n.03: any member of the mint family of plants
# mint.n.04: the leaves of a mint plant used fresh or candied
# mint.n.05: a candy that is flavored with a mint oil
# mint.n.06: a plant where money is coined by authority of the government

# %%
wn.synset('mint.n.04').part_holonyms()
# Out:
# [Synset('mint.n.02')]

# %%
wn.synset('mint.n.04').substance_holonyms()
# Out:
# [Synset('mint.n.05')]

# %% [markdown]
# There are also relationships between verbs. For example, the act of walking involves the act of stepping, so walking entails stepping. Some verbs have multiple entailments:

# %%
print(wn.synset('walk.v.01').entailments() )
print( wn.synset('eat.v.01').entailments())
print(wn.synset('tease.v.03').entailments())
# Out:
# [Synset('step.v.01')]
# [Synset('chew.v.01'), Synset('swallow.v.01')]
# [Synset('arouse.v.07'), Synset('disappoint.v.01')]

# %% [markdown]
# Some lexical relationships hold between lemmas, e.g., antonymy:

# %%
print(wn.lemma('supply.n.02.supply').antonyms())
print(wn.lemma('rush.v.01.rush').antonyms())
print(wn.lemma('horizontal.a.01.horizontal').antonyms())
print(wn.lemma('staccato.r.01.staccato').antonyms())
# Out:
# [Lemma('demand.n.02.demand')]
# [Lemma('linger.v.04.linger')]
# [Lemma('inclined.a.02.inclined'), Lemma('vertical.a.01.vertical')]
# [Lemma('legato.r.01.legato')]

# %%
#You can see the lexical relations, and the other methods defined on a synset, using dir(), for example: 
dir(wn.synset('harmony.n.02'))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_hypernyms',
#  '_definition',
#  '_examples',
#  '_frame_ids',
#  '_hypernyms',
#  '_instance_hypernyms',
#  '_iter_hypernym_lists',
#  '_lemma_names',
#  '_lemma_pointers',
#  '_lemmas',
#  '_lexname',
#  '_max_depth',
#  '_min_depth',
#  '_name',
#  '_needs_root',
#  '_offset',
#  '_pointers',
#  '_pos',
#  '_related',
#  '_shortest_hypernym_paths',
#  '_wordnet_corpus_reader',
#  'also_sees',
#  'attributes',
#  'causes',
#  'closure',
#  'common_hypernyms',
#  'definition',
#  'entailments',
#  'examples',
#  'frame_ids',
# ...

# %% [markdown]
# ##5.4 Semantic Similarity##
#
# NLTK CH2 Section 5.4.
#
#
# We have seen that synsets are linked by a complex network of lexical relations. Given a particular synset, we can traverse the WordNet network to find synsets with related meanings. Knowing which words are semantically related is useful for indexing a collection of texts, so that a search for a general term like vehicle will match documents containing specific terms like limousine.
#
# Recall that each synset has one or more hypernym paths that link it to a root hypernym such as entity.n.01. Two synsets linked to the same root may have several hypernyms in common (cf 5.1). If two synsets share a very specific hypernym — one that is low down in the hypernym hierarchy — they must be closely related.

# %%
wn.synset('right_whale.n.01').name()
rtwhale = wn.synset('right_whale.n.01')
print(rtwhale)
# Out:
# Synset('right_whale.n.01')

# %%
rtwhale = wn.synset('right_whale.n.01')

orca = wn.synset('orca.n.01')
minke = wn.synset('minke_whale.n.01')
tortoise = wn.synset('tortoise.n.01')
novel = wn.synset('novel.n.01')

print(rtwhale.lowest_common_hypernyms(minke))

print(rtwhale.lowest_common_hypernyms(orca))

print(rtwhale.lowest_common_hypernyms(tortoise))

print(rtwhale.lowest_common_hypernyms(novel))
# Out:
# [Synset('baleen_whale.n.01')]
# [Synset('whale.n.02')]
# [Synset('vertebrate.n.01')]
# [Synset('entity.n.01')]

# %% [markdown]
# ### Is "orca" more similar to "tortoise" or to "book"
#
#
# We have seen that synsets are linked by a complex network of lexical relations. Given a particular synset, we can traverse the WordNet network to find synsets with related meanings. Knowing which words are semantically related is useful for indexing a collection of texts, so that a search for a general term like vehicle will match documents containing specific terms like limousine.
#
# Recall that each synset has one or more hypernym paths that link it to a root hypernym such as entity.n.01. Two synsets linked to the same root may have several hypernyms in common (cf 5.1).
#
# *If two synsets share a very specific hypernym — one that is low down in the hypernym hierarchy — they must be closely related.*
#
# Of course we know that whale is very specific (and baleen whale even more so), while vertebrate is more general and entity is completely general. We can quantify this concept of generality by looking up the depth of each synset:

# %%
 	
print(wn.synset('baleen_whale.n.01').min_depth())

print(wn.synset('whale.n.02').min_depth())
# Out:
# 14
# 13

# %%
print(wn.synset('vertebrate.n.01').min_depth())

print(wn.synset('entity.n.01').min_depth())
# Out:
# 8
# 0

# %%
print( rtwhale.path_similarity(minke))

print( rtwhale.path_similarity(orca))

print( rtwhale.path_similarity(tortoise))

print( rtwhale.path_similarity(novel))
# Out:
# 0.25
# 0.16666666666666666
# 0.07692307692307693
# 0.043478260869565216

# %% [markdown]
# Similarity measures have been defined over the collection of WordNet synsets which incorporate the above insight. For example, path_similarity assigns a score in the range 0–1 based on the shortest path that connects the concepts in the hypernym hierarchy (-1 is returned in those cases where a path cannot be found). Comparing a synset with itself will return 1. Consider the above similarity scores, relating right whale to minke whale, orca, tortoise, and novel. Although the numbers won't mean much, they decrease as we move away from the semantic space of sea creatures to inanimate objects.

# %% [markdown]
# Note
#
# Several other similarity measures are available; you can type help(wn) for more information. NLTK also includes VerbNet, a hierarhical verb lexicon linked to WordNet. It can be accessed with nltk.corpus.verbnet.
